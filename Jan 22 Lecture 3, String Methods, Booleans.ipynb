# %%
attendance_code = 'BZMGJ'
print(attendance_code[0:4])
# Out:
# BZMG

# %%
message = 'Hello, world.'
length = len(message)
print(length)
# Out:
# 13

# %% [markdown]
# ## Using string methods

# %%
uppercase_text = message.upper()
print(uppercase_text)
# Out:
# HELLO, WORLD.

# %% [markdown]
# ### Finding the index of a substring

# %%
index = message.index('world')
print(index)
# Gives you the index (place) in your string where your subindex starts. 
# Will give you the earliest index.
# Out:
# 7

# %% [markdown]
# ### Replacing a substring

# %%
new_text = message.replace('Hello', 'Hi')
print(new_text)
# Out:
# Hi, world.

# %%
name = 'Michael Jackson'
print(name[-2], name[0:4])
# Out:
# o Mich

# %% [markdown]
# ### Print every even index.

# %%
name[0::2]
# First colon indicates start and end indecies, excluding the ending index. 
# The second colon indicates the "skip".
# Out:
# 'McalJcsn'

# %% [markdown]
# ### Concatenating strings.

# %%
statement = name + ' is the best. '
print(statement)
# Out:
# Michael Jackson is the best.

# %% [markdown]
# ### Repeating strings.

# %%
statement*3
# Out:
# 'Michael Jackson is the best. Michael Jackson is the best. Michael Jackson is the best. '

# %% [markdown]
# ### The Boolean Datatype.

# %%
x = 10
y = 5

comparison_1 = x>y
comparison_2 = x<y

if comparison_1:
    print('x is greater than y')
# Out:
# x is greater than y

# %% [markdown]
# ### Equivalence shorthand.

# %%
print('x is equal to y:', x==y)
print('x is not equal to y:', x!=y)
print('x is greater than or equal to y:', x>=y)
print('x is less than or equal to y:', x<=y)
# Out:
# x is equal to y: False
# x is not equal to y: True
# x is greater than or equal to y: True
# x is less than or equal to y: False

# %% [markdown]
# ### Converting integer to float

# %%
x_float = float(x)
print(type(x_float))
# Out:
# <class 'float'>

# %% [markdown]
# ### How casting Datatypes can destroy data.

# %%
euler_number = 2.71828
int(euler_number)
# Out:
# 2

# %% [markdown]
# ### Going from a string to an integer.

# %%
ex_string = '1 or 2 people'
number_list = [int(ex_string[0]), int(ex_string[5])]
print(number_list)
# Out:
# [1, 2]

# %% [markdown]
# ### Rounding numbers.

# %%
round(number=euler_number,ndigits=5)
# Out:
# 2.71828

# %% [markdown]
# ### Basic usage of input.

# %%
name = input('Enter your name: ')
print(f'Hello, {name}!')
# Out:
# Hello, xaacac!

# %%
alphabet = 'abcdefghijklmnopqrstuvwxyz'

def convert_string_to_int(input_string: str) -> int:
    num_list = []
    for char in input_string:
        num = alphabet.index(char)
        num_list.append(num)
    return num_list.sum()

convert_string_to_int('xrrs')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 10
#       7         num_list.append(num)
#       8     return num_list.sum()
# ---> 10 convert_string_to_int('xrrs')
#
# Cell In[48], line 8, in convert_string_to_int(input_string)
#       6     num = alphabet.index(char)
#       7     num_list.append(num)
# ----> 8 return num_list.sum()
#
# AttributeError: 'list' object has no attribute 'sum'
