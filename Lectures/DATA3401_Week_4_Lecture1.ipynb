# %% [markdown]
# Attendance Code: JLMGD

# %% [markdown]
# #Week 4-Function
# Pre-defined functions
#
# User-defined functions

# %%
number=3.1415926
rounded_num=round(number,2)
print(rounded_num)
type(rounded_num)
# Out:
# 3.14
# float

# %%
#Example: Fortmat a float as string with two decimal places
num=3.14159
formatted_num= f"{num:.2f}" # formats the number as a string with two decimal places.
print(formatted_num)
type(formatted_num)
# Out:
# 3.14
# str

# %% [markdown]
# ## Numerical functions:
# abs()
# round()
# min()
# max()
# sum
#
# ## String Functions:
# len(): Return the length of a string or sequence.
# str(): converts value to string
# int(): Converts string to integer
# float():Converts string to floating-point number.

# %%
num=[1,2,3,4,5,6,15]
Total=sum(num)
print(Total)
print(max(num))
print(min(num))
print(len(num))
# Out:
# 36
# 15
# 1
# 7

# %%
max(num)
# Out:
# 6

# %% [markdown]
# Defining a Function

# %%
def function_name(parameters): # Parameters or Arguments
   #Function body
   #Code to be executed
   return value

# %%
def function_name(input_arg_1, input_arg_2,....,input_arg_N):
  #Code to be executed
  return return_variable # optional

# %%
def greet(): # This function greets the user with a simple message.
   print("Hello there! Welcome to our program")

# %%
greet()
# Out:
# Hello there! Welcome to our program

# %%
def greet(username):
   print(f"Hello,{username}! How are you?")

# %%
greet("Alice")
greet("Bob")
greet("Brian")
# Out:
# Hello,Alice! How are you?
# Hello,Bob! How are you?
# Hello,Brian! How are you?

# %%
def add(a):
  b=a+1
  print(a,"if you add one", b)
  return(b)

add(6)
# Out:
# 6 if you add one 7
# 7

# %%
def Mult(a,b):
  c=a*b
  return(c)

# %%
result=Mult(12,3)
result
# Out:
# 36

# %%
X=Mult(4,"Michael Jackson ")
X
# Out:
# 'Michael Jackson Michael Jackson Michael Jackson Michael Jackson '

# %% [markdown]
# Types of Arguments:
# - **Position Arguments**:
# - **Keyword Arguments**
# - **Arbitrary Arguments**

# %%
def greet(first_name, last_name):
  print(f"Hello,{first_name} {last_name}!")

greet("John", "Michael")
# Out:
# Hello,John Michael!

# %%
def mypet(name, animal_type):
  print(f'\n name of animal is {name}.')
  print(f'\n My {name} is a {animal_type}.')

# %%
mypet('peanut','Dog')
# Out:
#  name of animal is peanut.
#
#  My peanut is a Dog

# %%
#round the return value to 2

def calculate_cylinder_volume(radius, height):
  #calculate the volume of the cylinder
  volume=3.1415*radius**2 * height
  rounded_volume=round(volume, 2)
  return rounded_volume

# %%
a=6
b=10
cylinder_volume=calculate_cylinder_volume(a,b)
print(cylinder_volume)
# Out:
# 1130.97
