# %% [markdown]
# You can use the following syntax to apply different styles to your text.

# %% [markdown]
# **This text is bold**
#
# *This text is italic.*
#
# ***This text is bold and italic***
#
# ~~This text is strikethrough.~~

# %% [markdown]
# # This is an h1 header
# ## This is an h2 header
# ### This is an h3 header
# #### This is an h4 header

# %% [markdown]
# - Item 1
# - Item 2
# - Item 3
#
# + Item 1
# + Item 2
# + Item 3
#
# * Item 1
# * Item 2
# * Item 3

# %%
'This is my string'
# Out:
# 'This is my string'

# %%
"This is also my string"
# Out:
# 'This is also my string'

# %%
print("Hello world")
# Out:
# Hello world

# %%
print("This\n is\n a multiple\n line string")
# Out:
# This
#  is
#  a multiple
#  line string

# %%
print('''This
is
a multiple
line string''')
# Out:
# This
# is
# a multiple
# line string

# %% [markdown]
# 1. Assigning a value to a variable

# %%
age=25
salary=2500
name="Alice"

# %%
print(name)
print(age)
print(salary)
# Out:
# Alice
# 25
# 2500

# %%
result=(5+3)**2
print(result)
# Out:
# 64

# %%
6/(2+3)
# Out:
# 1.2

# %%
abs(-3.5)
# Out:
# 3.5

# %%
int(-10.256)
# Out:
# -10

# %%
int(abs(-10.256))
# Out:
# 10

# %%
x=10
y=5

print("The sum is",x+y)
print("Difference",x-y)
print("Product",x*y)
# Out:
# The sum is 15
# Difference 5
# Product 50

# %%
city="Arlington"
Temp=14

print("The temperature in", city, "is", Temp, "in Celsius.")
# Out:
# The temperature in Arlington is 14 in Celsius.

# %%
name = "Alice"
price=20
product="Pen"

print(f"{name} has a box within ${price} {product} inside.")
print("Nme is ",name, "Type:",type(name))
# Out:
# Alice has a box within $20 Pen inside.
# Nme is  Alice Type: <class 'str'>

# %%
price=str(20)
print(price, "type",type(price))
# Out:
# 20 type <class 'str'>

# %%
num1=5
type(num1)
# Out:
# int

# %%
num2=6.5
type(num2)
# Out:
# float

# %%
num1+num2
# Out:
# 11.5

# %%
24/4
# Out:
# 6.0

# %%
pi=3.14
Temp=10.5
price=9.99

radius=5.0

area=pi*radius**2

discounted_new=price*0.8

# %%
print(area)
print(discounted_new)
# Out:
# 78.5
# 7.992000000000001

# %%
print("Python")
print("\tpython")
print("\t\tpython")
# Out:
# Python
# 	python
# 		python

# %%
name="Micheal Jackson"
print(name[4])
# Out:
# e

# %%
print(name[0])
# Out:
# M

# %%
print(name[-3])
# Out:
# s

# %%
name[0:4]
# Out:
# 'Mich'

# %%
name1="ce"

# %%
name1[0:3]
# Out:
# 'ce'
