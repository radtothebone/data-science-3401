# %% [markdown]
# # **Lab 11.Data Visualization (Questions)**

# %% [markdown]
# # **Assignment Submission Guidelines**
#
#
# ### **Steps to Submit Your Lab Assignments Using Google Colab**
#
# 1. **Submission Deadline:**
#    - All assignments must be submitted **no later than 23:59 PM tonight**.
#    - Late submissions will not be accepted unless prior arrangements have been made by the TAs.
#
# 2. **Complete Your Work:**
#    - Finish your work in Google Colab and ensure that your notebook is saved.
#
# 3. **Submit Your Assignment on Canvas:**
#    - Log in to **Canvas** and navigate to the assignment submission page.
#
# 4. **File Naming Convention:**
#    - Please name your files as follows: `Lastname_Firstname_AssignmentName`
#    - Example: `Alex_John_Lab11.ipynb` `Alex_John_lab11.pdf`.
#
# 5. **Technical Issues:**
#    - If you encounter any technical issues with Canvas or your submission, please contact the TAs immediately **before the deadline** to avoid penalties.

# %% [markdown]
# # **Questions**

# %% [markdown]
# ## Please use the **churn** dataset to answer these questions.

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ### **Question 1**

# %% [markdown]
# ### Create a bar chart to visualize the distribution of 'Geography' among customers.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('Churn.csv')

sns.countplot(data=df, x='Geography')
# Out:
# <Axes: xlabel='Geography', ylabel='count'>

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ### **Question 2**

# %% [markdown]
# ### Create a histogram to visualize the distribution of 'Age' among customers

# %%
sns.histplot(data=df, x='Age')
plt.show()

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ### **Question 3**

# %% [markdown]
# ### Create a pie chart to show the proportion of 'Gender' in the dataset

# %%
# I know there must be a more efficient way to do this, but I missed the early part of the lab. 
pct_female = round(df[df['Gender'] == 'Female'].shape[0]/df.shape[0], 2)
pct_male = 1 - pct_female

plt.pie([pct_female, pct_male], labels=['Female', 'Male'])
plt.show()

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ### **Question 4**

# %% [markdown]
# ### Create a boxplot for 'CreditScore' to identify outliers

# %%
# Seems odd to have a box plot for a single category numerical value like this
sns.boxplot(df, y='CreditScore')
plt.show()

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ### **Question 5**

# %% [markdown]
# ### Create a scatter plot of 'Age' vs. 'Balance' to explore the relationship between these two variables

# %%
sns.scatterplot(data=df, x='Age', y='Balance')
plt.show()

# %% [markdown]
# ---
#
#
#
# ---
#
#
# ---

# %% [markdown]
# ### **Question 6**

# %% [markdown]
# ### Create a line chart to visualize the change in 'NumOfProducts' over 'Age'.

# %%
sns.lineplot(df, x='Age', y='NumOfProducts')
plt.show()

# %% [markdown]
# ### **Question 7**

# %% [markdown]
# ### Create a bar chart to show the count of 'Exited' customers (churned vs. retained).

# %%
# Took some research to get the x labels here but 
# I'm not 100% sure what value means retained or churned. 
ax = sns.countplot(data=df, x='Exited')
ax.set_xticks([0,1])
ax.set_xticklabels(['Retained', 'Churned'])
plt.show()

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ### **Question 8**

# %% [markdown]
# ### Create a violin plot for 'Tenure' and 'Age' to compare their distributions.

# %%
sns.violinplot(data=df, x='Tenure', y='Age')
plt.show()

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ### **Question 9**

# %% [markdown]
# ### Create a bar chart to show the count of 'HasCrCard' (having vs. not having a credit card).

# %%
ax = sns.countplot(data=df, x='HasCrCard')
ax.set_xticks([0, 1])
ax.set_xticklabels(['No Credit Card', 'Has Credit Card'])
plt.show()

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ### **Question 10**

# %% [markdown]
# ### Create a bar chart to visualize the distribution of 'NumOfProducts' for customers with different 'Tenure' values.

# %%
count_df = df.groupby(['Tenure', 'NumOfProducts']).size().reset_index(name='Count') # This took a long time.

sns.barplot(data=count_df, x='Tenure', y='Count', hue='NumOfProducts')
plt.show()

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ### **Question 11**

# %% [markdown]
# ### How does the average balance of customers change with age? Create a line plot showing the average 'Balance' for each 'Age' group.

# %%
# Converted to dataframe to suppress a warning about how data cannot be a series. 
balance_by_age = pd.DataFrame(df.groupby('Age')['Balance'].mean())

sns.lineplot(data=balance_by_age, x='Age', y='Balance')
# Out:
# <Axes: xlabel='Age', ylabel='Balance'>

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ### **Question 12**

# %% [markdown]
# ### Using the 'Churn' dataset, create a 2x2 grid of subplots. Each subplot should display one of the following:
#
# - 1. A histogram showing the distribution of 'Age'.
# - 2. A bar plot showing the count of customers in each 'Geography' category.
# - 3. A scatter plot comparing 'CreditScore' and 'Balance'.
# - 4. A boxplot showing the distribution of 'EstimatedSalary'.

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Histogram of Age
sns.histplot(data=df, x='Age', ax=axes[0, 0])
axes[0, 0].set_title('Distribution of Age')

# Bar plot of Geography count
sns.countplot(data=df, x='Geography', ax=axes[0, 1])
axes[0, 1].set_title('Customer Count by Geography')

# Scatter plot of CreditScore vs Balance
sns.scatterplot(data=df, x='CreditScore', y='Balance', ax=axes[1, 0])
axes[1, 0].set_title('CreditScore vs Balance')

# Boxplot of EstimatedSalary
sns.boxplot(data=df, y='EstimatedSalary', ax=axes[1, 1])
axes[1, 1].set_title('Distribution of EstimatedSalary')


plt.show()
