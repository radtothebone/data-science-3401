# %% [markdown]
# # **Lab 8 : Numpy and Random Variables (Questions)**

# %% [markdown]
# # **Assignment Submission Guidelines**
#
#
# ### **Steps to Submit Your Lab Assignments Using Google Colab**
#
# 1. **Submission Deadline:**
#    - All assignments must be submitted **no later than 23:59 PM tonight**.
#    - Late submissions will not be accepted unless prior arrangements have been made by the TAs.
#
# 2. **Complete Your Work:**
#    - Finish your work in Google Colab and ensure that your notebook is saved.
#
# 3. **Submit Your Assignment on Canvas:**
#    - Log in to **Canvas** and navigate to the assignment submission page.
#
# 4. **File Naming Convention:**
#    - Please name your files as follows: `Lastname_Firstname_AssignmentName`
#    - Example: `Alex_John_Lab8.ipynb` and `Alex_John_Lab8.pdf`
#
# 5. **Technical Issues:**
#    - If you encounter any technical issues with Canvas or your submission, please contact the TAs immediately **before the deadline** to avoid penalties.

# %% [markdown]
# ## **Questions**

# %% [markdown]
# ---

# %% [markdown]
# ## **Question 1:** (5 Points)

# %% [markdown]
# Write a NumPy code to create an array of integers from 1 to 5.

# %% [markdown]
# ---

# %% [markdown]
# ## **Question 2:** (5 Points)

# %% [markdown]
# Write a NumPy code to create a 2D array with shape (3, 4) containing all zeros.

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ## **Question 3:** (5 Points)

# %% [markdown]
# Write a NumPy code to create an array of 5 random floating-point numbers between 0 and 1.

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## **Question 4:** (5 Points)

# %% [markdown]
# Write a NumPy code to add two arrays `arr1` and `arr2` element-wise.

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## **Question 5:** (5 Points)

# %% [markdown]
# Write a NumPy code to calculate the mean of all elements in an array `arr`.

# %% [markdown]
# ## **Question 6:** (5 Points)

# %% [markdown]
# Write a NumPy code to reshape a 1D array `arr` with shape (8,) into a 2D array with shape (2, 4).

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## **Question 7:** (5 Points)

# %% [markdown]
# Write a NumPy code to calculate the dot product of two arrays arr1 and arr2.

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## **Question 8:** (5 Points)

# %% [markdown]
# Write a NumPy code to find the indices of the maximum and minimum values in an array `arr`.

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## **Question 9:** (5 Points)

# %% [markdown]
# Write a NumPy code to calculate the element-wise square root of an array arr.

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## **Question 10:** (5 Points)

# %% [markdown]
# Write a NumPy code to calculate the sum of each column in a 2D array `arr`.

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## **Question 11:** (5 Points)

# %% [markdown]
#  Write a NumPy code to compute the element-wise multiplication of two
# arrays `arr1` and `arr2`.

# %% [markdown]
# ## **Question 12:** (5 Points)

# %% [markdown]
# Write a NumPy code to calculate the mean of each row in a 2D array `arr`.

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## **Question 13:** (5 Points)

# %% [markdown]
# Write a NumPy code to sort the elements in an array `arr` in descending order.

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## **Question 14:** (5 Points)

# %% [markdown]
# Write a NumPy code to calculate the matrix multiplication of  two 2D arrays `arr1` and `arr2`.

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## **Question 15:** (5 Points)

# %% [markdown]
# Write a NumPy code to perform element-wise comparison between two arrays
# `arr1` and `arr2` and return a new array with True for elements that are greater
# in `arr1` and False otherwise.

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## **Question 16:** (5 Points)

# %% [markdown]
# Write a Python program using NumPy to solve the following system of linear equations:

# %%
2x + 3y = 12
4x - 2y = 6

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## **Question 17:** (5 Points)

# %% [markdown]
# Create an array of 20 random integers between 1 and 100. Use a NumPy conditional statement to replace all numbers greater than 50 with the number -1.

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ## **Question 18:** (5 Points)

# %% [markdown]
# Create a 5x5 matrix with values ranging from 1 to 25. Extract a 3x3 sub-matrix from the center of this matrix.

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ## **Question 19:** (5 Points)

# %% [markdown]
# Create an array of 30 random integers between 10 and 100. Use NumPy to identify elements that are either multiples of 3 or multiples of 5 and replace them with -1.

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ## **Question 20:** (5 Points)

# %% [markdown]
# **Complex Array Filtering**:  Create an array of 100 random floats. Use NumPy to find all values that are within one standard deviation from the mean of the array. Return these values sorted in ascending order.
