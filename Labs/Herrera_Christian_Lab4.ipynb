# %% [markdown]
# # **Lab 4. Data Structure**

# %% [markdown]
# # **Assignment Submission Guidelines**
#
#
# ### **Steps to Submit Your Lab Assignments Using Google Colab**
#
# 1. **Submission Deadline:**
#    - All assignments must be submitted **no later than 23:59PM Friday(02/13)**.
#    - Late submissions will not be accepted unless prior arrangements have been made by the TAs.
#
# 2. **Complete Your Work:**
#    - Finish your work in Google Colab and ensure that your notebook is saved.
#
# 3. **Submit Your Assignment on Canvas:**
#    - Log in to **Canvas** and navigate to the assignment submission page.
#
# 4. **File Naming Convention:**
#    - Please name your files as follows: `Lastname_Firstname_AssignmentName`
#    - Example: `Alex_John_Lab4.ipynb` and `Alex_John_Lab4.pdf`
#
# 5. **Technical Issues:**
#    - If you encounter any technical issues with Canvas or your submission, please contact the TAs immediately **before the deadline** to avoid penalties.

# %% [markdown]
# # **Questions**

# %% [markdown]
# ---

# %% [markdown]
# ### **Question 1 (5 Points):**

# %% [markdown]
# ##### Write a Python program that takes two numbers as input from the user and performs addition, subtraction, multiplication, and division onthose numbers.

# %% [markdown]
# ### **Question 2 : Celsius to Fahrenheit Conversion (5 Points)**

# %% [markdown]
# ##### Write a Python program that asks the user to enter a temperature in Celsius and then converts it to Fahrenheit.

# %% [markdown]
# ### **Question 3 (5 Points):**

# %% [markdown]
# ##### Using Range () generate a list of every 3rd number from 0 to 20. What do you expect the output to be?

# %% [markdown]
# ----

# %% [markdown]
# ## **Question 4 (5 Points):**

# %%
list1=["a", "b","c","d","e","f","g","h"]

# %% [markdown]
# ##### Using the list above, Write the code the output is **"['h', 'g', 'f', 'e', 'd', 'c', 'b', 'a']"**

# %% [markdown]
# ### **Question 5. (5 Points):**

# %% [markdown]
# ##### Write the code the output is **['h', 'e', 'b']**

# %% [markdown]
# ### **Question 6 (5 Points):**
#
# **Boolean Comparison:**
# Write a Python program that checks if the number a = 5 is greater than b = 15 and prints a Boolean result.

# %% [markdown]
# ## **Question 7 (5 Points):**
#
# **String Repetition:**
# Write a Python program that repeats the string s = 'Hello' 5 times and prints the result.

# %% [markdown]
# ### **Question 12 (5 Points):**

# %% [markdown]
# ##### Create a list named my_list with the elements 5, 2, 8, 1, and 10 in that order. Sort my_list in ascending order using the sort() method. and print it

# %% [markdown]
# ### **Question 9 (5 Points):**

# %% [markdown]
# ##### Create an empty list named fruits. Add the elements "apple", "banana", and "cherry" to fruits using the append() method.
#
# ##### Print fruits to verify the contents.  Print fruits to verify the contents.

# %% [markdown]
# ### **Question 10 (5 Points):**

# %% [markdown]
# ##### Create a list named numbers with the elements 1, 2, 3, 4, 5.
#
# ##### Insert the number 10 at index 2 in numbers using the insert() method.
#
# ##### Print numbers to see the modified list.

# %% [markdown]
# ### **Question 11 (10 Points):**

# %% [markdown]
# ##### Create a list named my_list with the elements "apple", "banana", "cherry", "orange".
#
# ##### Delete the element at index 2 in my_list using the del statement.
#
# ##### Print my_list to see the modified list.

# %% [markdown]
# ## **Question 12 (10 Points):**

# %% [markdown]
# #### Create a list named my_list with the elements 1, 2, 3, 4, 5.
#
# - Use list slicing to print the elements from index 1 to 3 (inclusive) in my_list.
#
# - Create a list named my_list with the elements "apple", "banana", "cherry", "orange".
#
# - Modify the element at index 1 in my_list to "grape".
#
# - Print my_list to see the modified list.

# %% [markdown]
# ### **Question 13 (10 Points):**

# %% [markdown]
# Write a Python program that takes a dictionary of student names and their corresponding scores as input and returns the name of the student with the highest score.

# %%
# Test the function
scores = {'Alice': 85, 'Bob': 72, 'Charlie': 90, 'David': 88}

# %% [markdown]
# ### **Question 14 (10 Points):**

# %% [markdown]
# Write a Python program that takes a list of tuples, where each tuple contains a student's name and their corresponding score, and returns a dictionary where the keys are the student names and the values are their average scores.

# %%
# Test the function
student_scores = [('Alice', 85), ('Bob', 72), ('Charlie', 90),('Bob', 75), ('Alice', 88), ('Charlie', 94)]

# %% [markdown]
# ## **Question 15 (10 Points):**

# %% [markdown]
# Write a Python program that takes a list of tuples, where each tuple contains a student's name and their corresponding scores in three subjects, and returns a list of students who have scored above a certain threshold in all subjects. Your threshold can be 80.

# %%
# Test the function
students_scores = [('Alice', (85, 90, 88)),
                   ('Bob', (72, 80, 78)),
                   ('Charlie', (90, 92, 94)),
                   ('David', (88, 85, 81))]
