# %% [markdown]
# Basics of operating jupyter notebooks.

# %% [markdown]
# **This text is bold** <br>
# *This text is italicized*<br>
# <b>This text is also bold</b><br>
# <i>This text is also italicized</i>
# -- This text is struckthrough --

# %% [markdown]
# # H1 header
# ## H2 header
# ### H3 header

# %% [markdown]
# - item 1
# - item 2
# - item 3
#
# * item 4
# * item 5
# * item 6
#
# + item 7
# + item 8
# + item 9

# %%
print('This is a string.', "This is also a string")
# Out:
# This is a string. This is also a string

# %%
print('This is a multi-line sting \nHello, new line.')
# Out:
# This is a multi-line sting
# Hello, new line.

# %%
print('''This is also
      a multi-line
      string.''')
# Out:
# This is also
#       a multi-line
#       string.

# %% [markdown]
# # Working with variables.

# %%
age = 25
salary = 25000
name = 'Alice'

# %% [markdown]
# ### Referencing a variable.

# %%
print(name, salary, age)
# Out:
# Alice 25000 25

# %% [markdown]
# # Math in python.

# %% [markdown]
# \+ $\rightarrow$ addition <br>
# \- $\rightarrow$ subtraction<br>
# \* $\rightarrow$ multiplication<br>
# / $\rightarrow$ division <br>
# ** $\rightarrow$ exponentiation<br>
# // $\rightarrow$ mod

# %% [markdown]
# ### Working with math in python.

# %%
print(24 + 3)
# Out:
# 27

# %%
6/(2+3)
# Out:
# 1.2

# %% [markdown]
# ### Calling math functions

# %%
print('Absolute value of -230 =', abs(-230), 'Integer value of 2424.123 =', int(2424.123))
# Out:
# Absolute value of -230 = 230 Integer value of 2424.123 = 2424

# %% [markdown]
# ### Printing strings with variables.

# %%
x = 10 
y = 5

print('The sum of x and y is equal to', x + y)
# Out:
# The sum of x and y is equal to 15

# %% [markdown]
# ### Using f strings to print variables.

# %%
city = 'Arlington'
temperature = 14

print(f'The temperature in {city} is {temperature}')
# Out:
# The temperature in Arlington is 14

# %%
name = 'Alice'
pen_price = 20

print(f'{name} has a ${pen_price} pen in her box.')
# Out:
# Alice has a $20 pen in her box.

# %% [markdown]
# ### Changing Datatypes.

# %%
pen_price = str(pen_price)

# %% [markdown]
# Words are strings, numbers can be either integers or floats.

# %%
number_1 = 5
number_2 = 5.0
print(type(number_1), type(number_2))
# Out:
# <class 'int'> <class 'float'>

# %%
import math
pi = math.pi
radius = 5.0
area = pi*radius**2
print(area)

temp = 10.6
# Out:
# 78.53981633974483

# %% [markdown]
# Indexing and printing characters of a string. Note how the last index is not included.

# %%
name = 'Michael Jackson'
print(name[4], name[-3], name[0:4])
# Out:
# a s Mich
