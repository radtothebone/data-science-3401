# %% [markdown]
# ### Class Structure notes

# %% [markdown]
# No midterms. <br>
# 1 week to finish homework, lab assignments must be completed during the lab time. <br>
# All homework and labs must be submitted through canvas. All submissions must follow the provided naming convention.

# %% [markdown]
# #### Basic computer shit.

# %% [markdown]
# Finding $134$ in binary $\rightarrow 128 + 6 + 2 \rightarrow 1000000 + 00000100 + 00000010$<br>
# What is $10010011$? $\rightarrow 128 + 16 + 2 + 1$
