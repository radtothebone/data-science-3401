# %%
# The super class
class Pizza:
    def __init__(self, name):
        self.name = name
        self.topping = []
    def add_topping(self, topping):
        self.topping.append(topping)
    def bake(self):
        print(f'Baking {self.name} Pizza with topping, {self.topping}')

# %%
class MargheritaPizza(Pizza):
