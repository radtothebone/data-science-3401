# %% [markdown]
# # **Homework10- Advance Pandas (Questions)**

# %% [markdown]
# # **Assignment Submission Guidelines**
#
#
# Please follow the guidelines below for submitting your assignment:
#
# 1. **Submission Deadline:**
#    - All assignments must be submitted **no later than 23:59 PM next Thursday (04/09)**.
#    - Late submissions will not be accepted unless prior arrangements have been made by the TAs.
#
# 2. **Complete Your Work:**
#    - Finish your work in Google Colab and ensure that your notebook is saved.
#
#
# 3. **Submit Your Assignment on Canvas:**
#    - Log in to **Canvas** and navigate to the assignment submission page.
#
#
# 4. **File Naming Convention:**
#    - Please name your files as follows: `Lastname_Firstname_AssignmentName`
#    - Example: `Alex_John_HW10.ipynb`, `Alex_John_HW10.pdf`
#
# 5. **Technical Issues:**
#    - If you encounter any technical issues with Canvas or your submission, please contact the TAs immediately **before the deadline** to avoid penalties.

# %% [markdown]
# # **Questions**

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# 1. Load the Startups dataset into a pandas DataFrame and display the first few rows. (5 Points)

# %%
import pandas as pd
df = pd.read_csv('startups.csv')

df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# 2. Find the number of rows and columns in the dataset. (5 Points)

# %%
print(f'rows: {df.shape[0]} cols: {df.shape[1]}')
# Out:
# rows: 50 cols: 5

# %% [markdown]
# ---
#
#
# ---

# %% [markdown]
# 3. Check for missing values in each column and handle them appropriately. (5 Points)

# %%
#df['R&D Spend'].isna().sum()

print(df.isna().sum())
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %% [markdown]
# ---
#
#
# ---

# %% [markdown]
# 4. Calculate the mean, median, and standard deviation of the 'R&D_Spend' column. (5 Points)

# %%
print('general stats:\n' , df['R&D Spend'].describe(), '\n') # The shortcut

# One by one
print('mean:', df['R&D Spend'].mean(),
      'median:',  df['R&D Spend'].median(),
      'std:',  df['R&D Spend'].std())
# Out:
# general stats:
#  count        50.000000
# mean      73721.615600
# std       45902.256482
# min           0.000000
# 25%       39936.370000
# 50%       73051.080000
# 75%      101602.800000
# max      165349.200000
# Name: R&D Spend, dtype: float64
#
# mean: 73721.6156 median: 73051.08 std: 45902.25648230753

# %% [markdown]
# ---
#
#
# ---

# %% [markdown]
# 5. Filter and create a new DataFrame containing companies located in a **California**. (5 Points)

# %%
cali_df = df[df['State'] == 'California']
cali_df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 1   162597.70       151377.59        443898.53  California  191792.06
# 6   134615.46       147198.87        127716.82  California  156122.51
# 9   123334.88       108679.17        304981.62  California  149759.96
# 11  100671.96        91790.61        249744.55  California  144259.40
# 13   91992.39       135495.07        252664.93  California  134307.35
# 16   78013.11       121597.55        264346.06  California  126992.93
# 20   76253.86       113867.30        298664.47  California  118474.03
# 25   64664.71       139553.16        137962.62  California  107404.34
# 32   63408.86       129219.61         46085.25  California   97427.84
# 34   46426.07       157693.92        210797.67  California   96712.80
# 37   44069.95        51283.14        197029.42  California   89949.14
# 39   38558.51        82982.09        174999.30  California   81005.76
# ...

# %% [markdown]
# ---
#
#
# ---

# %% [markdown]
# 6. Sort the dataset by 'Profit' in descending order. (5 Points)

# %%
sort_by_profit_df = df.sort_values('Profit', ascending=False)
sort_by_profit_df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %% [markdown]
# ---
#
#
# ---

# %% [markdown]
# 7. Group the data by 'State' and calculate the total 'Profit' for each state. (5 Points)

# %%
state_profit_df = df.groupby('State')['Profit'].sum()
state_profit_df
# Out:
# State
# California    1766387.98
# Florida       1900384.39
# New York      1933859.59
# Name: Profit, dtype: float64

# %% [markdown]
# ---
#
#
# ---

# %% [markdown]
# 8. Create a bar chart to visualize the total 'Profit' by 'State.' (5 Points)

# %%
import matplotlib.pyplot as plt
state_profit_df.plot(kind='bar')
plt.title('Profits of companies by state')
plt.ylabel('$ (B)') # I'm just guessing that this is in billios. 
plt.xlabel('State')
plt.show()

# %% [markdown]
# ---
#
#
# ---

# %% [markdown]
# 9. Calculate the correlation between 'R&D_Spend' and 'Profit.' (5 Points)

# %%
correlation = df['R&D Spend'].corr(df['Profit'])
print(f"Correlation between R&D Spend and Profit: {correlation:.4f}")
# Out:
# Correlation between R&D Spend and Profit: 0.9729

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# 10. Create a new column 'Total_Spend' that represents the sum of 'R&D_Spend,' 'Administration,' and 'Marketing_Spend' for each company. (5 Points)

# %%
df['Total_Spend'] = df[['R&D Spend', 'Administration', 'Marketing Spend']].sum(axis=1)
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit  \
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %% [markdown]
# 11. Calculate the average **R&D_Spend**, **Administration**, and **Marketing_Spend** for companies located in each **State** (5 Points)

# %%
df.groupby('State')[['R&D Spend', 'Administration', 'Marketing Spend']].mean()
# Out:
#                R&D Spend  Administration  Marketing Spend
# State
# California  64657.674118   120746.507059    182540.929412
# Florida     80724.016250   121768.897500    247323.551250
# New York    76195.062353   121543.470588    205346.015882

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# 12. Create a histogram to visualize the distribution of 'Profit.' (5 Points)

# %%
df['Profit'].plot(kind='hist', bins=20)
plt.show()

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# 13. Filter the dataset to include only companies with 'R&D_Spend' greater than a 12000. (5 Points)

# %%
high_rd_df = df[df['R&D Spend'] > 12000]
high_rd_df.head() # Only the top 5.
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit  \
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94
#
#    Total_Spend
# 0    774031.10
# 1    757873.82
# 2    662521.60
# 3    646243.88
# 4    599667.53

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# 14. Calculate the total 'Profit' for companies with 'Marketing_Spend' above a certain threshold. (5 Points)

# %%
threshold = 156991 # Top 5 companies only.
print(df[df['Marketing Spend'] > threshold]['Profit'].sum())
# Out:
# 4136608.24

# %% [markdown]
# 15. Replace any missing values in the 'Marketing_Spend' column with the mean spending of the dataset. (5 Points)

# %%
df['Marketing Spend'] = df['Marketing Spend'].fillna(df['Marketing Spend'].mean())
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit  \
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94
#
#    Total_Spend  Profit_Margin
# 0    774031.10       0.248390
# 1    757873.82       0.253066
# 2    662521.60       0.288369
# 3    646243.88       0.283023
# 4    599667.53       0.277133

# %% [markdown]
# ---
#
#
# ---

# %% [markdown]
# 16. Create a new column 'Profit_Margin' that represents the profit margin for each company (Profit / Total_Spend). (5 Points)

# %%
df['Profit_Margin'] = df['Profit']/df['Total_Spend']

df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit  \
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94
#
#    Total_Spend  Profit_Margin
# 0    774031.10       0.248390
# 1    757873.82       0.253066
# 2    662521.60       0.288369
# 3    646243.88       0.283023
# 4    599667.53       0.277133

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# 17. Sort the dataset by 'Profit_Margin' in descending order. (5 Points)

# %%
df.sort_values('Profit_Margin', ascending=False)
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit  \
# 48     542.05        51743.15             0.00    New York   35673.41
# 19   86419.70       153514.11             0.00    New York  122776.86
# 45    1000.23       124153.04          1903.93    New York   64926.08
# 32   63408.86       129219.61         46085.25  California   97427.84
# 43   15505.73       127382.30         35534.17    New York   69758.98
# 6   134615.46       147198.87        127716.82  California  156122.51
# 30   61994.48       115641.28         91131.24     Florida   99937.59
# 24   77044.01        99281.34        140574.81    New York  108552.04
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# 31   61136.38       152701.92         88218.23    New York   97483.56
# 44   22177.74       154806.14         28334.72  California   65200.33
# ...

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# 18. Calculate the average profit margin for companies in each 'State' and create a bar chart to display it. (5 Points)

# %%
df.groupby('State')['Profit_Margin'].mean().plot(kind='bar')
plt.title('Average Profit Margin by State')
plt.ylabel('Profit Margin')
plt.xlabel('State')
# Out:
# Text(0.5, 0, 'State')

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# 19. Find the maximum 'R&D_Spend' in each **State**. (5 Points)

# %%
df.groupby('State')['R&D Spend'].max()
# Out:
# State
# California    162597.70
# Florida       153441.51
# New York      165349.20
# Name: R&D Spend, dtype: float64
