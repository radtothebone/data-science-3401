# %%
class Car:
    def __init__(self, color, brand, speed) -> None:
        self.color = color
        self.brand = brand
        self.speed = speed
        self.fuel_level = 100
    
    def drive(self): # Simulates driving the car when called.
